# %%
import tensorflow as tf
from transformers import TFGPT2LMHeadModel, GPT2Tokenizer
import torch

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = TFGPT2LMHeadModel.from_pretrained('gpt2', pad_token_id = tokenizer.eos_token_id)

def generate_text(input_text, max_length=100):
    input_ids = tokenizer.encode(input_text, return_tensors='tf')
    outputs = model.generate(input_ids, max_length=max_length, do_sample=True, temperature=0.7)
    generated_text = tokenizer.decode(outputs[0], skip_special_tokens=True)
    return generated_text
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# All PyTorch model weights were used when initializing TFGPT2LMHeadModel.
#
# All the weights of TFGPT2LMHeadModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2LMHeadModel for predictions without further training.
# ...

# %%
prompt_given = "A Lion reading a book on a beach."
prompt_to_identify_objects = f"""
You are an AI assistant tasked with analyzing image generation prompts to identify the key objects and elements described in the text. Given the following prompt, list all the distinct objects, characters, or elements that are mentioned. Provide a clear and concise list of these items. The upper limit of objects should be 3.

Examples:
Prompt: "A cat sitting on a mat."
Objects/Elements:
1. Cat
2. Mat

Prompt: "A dog playing with a ball in the park."
Objects/Elements:
1. Dog
2. Ball
3. Park

Prompt: "A man riding a bicycle in the city."
Objects/Elements:
1. Man
2. Bicycle
3. City

Prompt: "A bird flying over a lake."
Objects/Elements:
1. Bird
2. Lake

Prompt: "A child building a sandcastle on the beach."
Objects/Elements:
1. Child
2. Sandcastle
3. Beach

Prompt: "{prompt_given}"
Objects/Elements:
1.
2.
3.
"""

generated_text = generate_text(prompt_to_identify_objects, max_length=300)
print("=============")
print(generated_text)
# Out:
# ...
#
# You are an AI assistant tasked with analyzing image generation prompts to identify the key objects and elements described in the text. Given the following prompt, list all the distinct objects, characters, or elements that are mentioned. Provide a clear and concise list of these items. The upper limit of objects should be 3.
#
# Examples:
# Prompt: "A cat sitting on a mat."
# Objects/Elements:
# 1. Cat
# 2. Mat
#
# Prompt: "A dog playing with a ball in the park."
# Objects/Elements:
# 1. Dog
# 2. Ball
# 3. Park
#
# Prompt: "A man riding a bicycle in the city."
# Objects/Elements:
# 1. Man
# 2. Bicycle
# 3. City
#
# Prompt: "A bird flying over a lake."
# Objects/Elements:
# 1. Bird
# 2. Lake
#
# Prompt: "A child building a sandcastle on the beach."
# Objects/Elements:
# 1. Child
# 2. Sandcastle
# 3. Beach
#
# Prompt: "A Lion reading a book on a beach."
# Objects/Elements:
# 1.
# 2.
# 3.
#
# This can be easily solved with a simple prompt:
#
# ...

# %%
# Install the OpenAI package
# !pip install openai

# Import necessary libraries
import openai

# %%
# Set your OpenAI API key
openai.api_key = 'your-api-key-here'

# Define the prompt
prompt_given = "A Lion reading a book on a beach."
prompt_to_identify_objects = f"""
You are an AI assistant tasked with analyzing image generation prompts to identify the key objects and elements described in the text. Given the following prompt, list all the distinct objects, characters, or elements that are mentioned. Provide a clear and concise list of these items. The upper limit of objects should be 3.

Examples:
Prompt: "A cat sitting on a mat."
Objects/Elements:
1. Cat
2. Mat

Prompt: "A dog playing with a ball in the park."
Objects/Elements:
1. Dog
2. Ball
3. Park

Prompt: "A man riding a bicycle in the city."
Objects/Elements:
1. Man
2. Bicycle
3. City

Prompt: "A bird flying over a lake."
Objects/Elements:
1. Bird
2. Lake

Prompt: "A child building a sandcastle on the beach."
Objects/Elements:
1. Child
2. Sandcastle
3. Beach

Prompt: "{prompt_given}"
Objects/Elements:
1.
2.
3.
"""

# Function to generate response from OpenAI's GPT-3/4
def generate_response(prompt, max_tokens=150):
    response = openai.Completion.create(
        engine="text-davinci-003",  # You can use "text-davinci-004" if available
        prompt=prompt,
        max_tokens=max_tokens,
        n=1,
        stop=None,
        temperature=0.7,
    )
    return response.choices[0].text.strip()

# Generate the response
generated_text = generate_response(prompt_to_identify_objects)
print("=============")
print(generated_text)
